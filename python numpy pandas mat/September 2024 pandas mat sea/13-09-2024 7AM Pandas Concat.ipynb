# %%
import pandas as pd

# %%
cars_sales = pd.read_csv('d:/data/cars/Car_sales_transactions.csv')
cars_sales
# Out:
#       Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0            1        Maruti Swift Dzire VDI  2014         450000     145500
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2            3      Honda City 2017-2020 EXi  2006         158000     140000
# 3            4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4            5        Maruti Swift VXI BSIII  2007         130000     120000
# ...        ...                           ...   ...            ...        ...
# 7901      8124             Hyundai i20 Magna  2013         320000     110000
# 7902      8125         Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126        Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127               Tata Indigo CR4  2013         290000      25000
# 7905      8128               Tata Indigo CR4  2013         290000      25000
#
# ...

# %%
sale_status = pd.read_csv('d:/data/cars/Sales_Status.csv')
sale_status
# Out:
#       Sales_ID Sold
# 0            1    Y
# 1            2    Y
# 2            3    Y
# 3            4    Y
# 4            5    Y
# ...        ...  ...
# 7901      8124    N
# 7902      8125    N
# 7903      8126    N
# 7904      8127    N
# 7905      8128    N
#
# [7906 rows x 2 columns]

# %%
cars = pd.concat(objs=[cars_sales,sale_status],axis=1)
cars
# Out:
#       Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0            1        Maruti Swift Dzire VDI  2014         450000     145500
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2            3      Honda City 2017-2020 EXi  2006         158000     140000
# 3            4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4            5        Maruti Swift VXI BSIII  2007         130000     120000
# ...        ...                           ...   ...            ...        ...
# 7901      8124             Hyundai i20 Magna  2013         320000     110000
# 7902      8125         Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126        Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127               Tata Indigo CR4  2013         290000      25000
# 7905      8128               Tata Indigo CR4  2013         290000      25000
#
# ...

# %%
emp1 = pd.read_csv('d:/NewData/EMP1.txt')
emp1
# Out:
#    empno ename
# 0   1001  ABCD
# 1   1002   XYZ
# 2   1003  PQRS
# 3   1004  EFGH
# 4   1005  MMMM
# 5   1006  PPPP
# 6   1007  IIII
# 7   1008  NNNN

# %%
emp2 = pd.read_csv('d:/NewData/EMP2.txt')
emp2
# Out:
#     sal  deptno
# 0  2500      20
# 1  1500      30
# 2  4000      10
# 3  1000      20
# 4  2500      10
# 5  5000      30
# 6  2400      10

# %%
pd.concat(objs=[emp1,emp2],axis=1,join='outer')
# Out:
#    empno ename     sal  deptno
# 0   1001  ABCD  2500.0    20.0
# 1   1002   XYZ  1500.0    30.0
# 2   1003  PQRS  4000.0    10.0
# 3   1004  EFGH  1000.0    20.0
# 4   1005  MMMM  2500.0    10.0
# 5   1006  PPPP  5000.0    30.0
# 6   1007  IIII  2400.0    10.0
# 7   1008  NNNN     NaN     NaN

# %%
df1 =  pd.read_csv('d:/data/Hotels/bangalore.csv')
df2 =  pd.read_csv('d:/data/Hotels/chennai.csv')
df3 =  pd.read_csv('d:/data/Hotels/delhi.csv')
df4 =  pd.read_csv('d:/data/Hotels/hyderabad.csv')
df5 =  pd.read_csv('d:/data/Hotels/mumbai.csv')
df6 =  pd.read_csv('d:/data/Hotels/kolkata.csv')

# %%
df1.columns
# Out:
# Index(['Hotel Name', 'Rating', 'Rating Description', 'Reviews', 'Star Rating',
#        'Location', 'Nearest Landmark', 'Distance to Landmark', 'Price', 'Tax'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Hotel Name', 'Rating', 'Rating Description', 'Reviews', 'Star Rating',
#        'Location', 'Nearest Landmark', 'Distance to Landmark', 'Price', 'Tax'],
#       dtype='object')

# %%
df6.columns
# Out:
# Index(['Hotel Name', 'Rating', 'Rating Description', 'Reviews', 'Star Rating',
#        'Location', 'Nearest Landmark', 'Distance to Landmark', 'Price', 'Tax'],
#       dtype='object')

# %%
df1.shape,df4.shape
# Out:
# ((101, 10), (75, 10))

# %%
df1['Rating Description'].value_counts()
# Out:
# Rating Description
# Very Good    67
# Excellent    28
# Good          5
# Name: count, dtype: int64

# %%
hotels = pd.concat(objs=[df1,df2,df3,df4,df5,df6],axis=0,ignore_index=True)
hotels
# Out:
#                                             Hotel Name  Rating  \
# 0                                   The Park Bangalore     3.9
# 1    Keys Select by Lemon Tree Hotels, Whitefield, ...     4.0
# 2              ITC Windsor - A Luxury Collection Hotel     4.4
# 3             Lemon Tree Premier Ulsoor Lake Bangalore     4.0
# 4    Keys Select by Lemon Tree Hotels, Hosur Road, ...     4.0
# ..                                                 ...     ...
# 575                          Hotel Gateway Continental     3.8
# 576                                     Hotel Air View     4.0
# 577                                 Hotel Casa Fortuna     3.9
# 578                                      Middleton Inn     3.5
# 579                         Hotel Sawood International     3.6
#
#     Rating Description  Reviews  Star Rating              Location  \
# 0            Very Good   4187.0          5.0                Ulsoor
# 1            Very Good   2201.0          4.0           Brookefield
# ...

# %%
hotels['Rating Description'].value_counts()
# Out:
# Rating Description
# Very Good    398
# Excellent    139
# Good          37
# Average        4
# Poor           1
# Name: count, dtype: int64

# %%
hotels[hotels['Rating Description']=='Average']
# Out:
#                    Hotel Name  Rating Rating Description  Reviews  \
# 284                  HOME@B11     2.3            Average      3.0
# 294             Centaur Hotel     2.5            Average    676.0
# 339  Katriya Hotel and Towers     2.8            Average   3250.0
# 371               The Manohar     2.7            Average    258.0
#
#      Star Rating         Location                     Nearest Landmark  \
# 284          NaN  East Of Kailash                                  NaN
# 294          3.0   Delhi Airport   Indira Gandhi International Airport
# 339          3.0       Somajiguda                                  NaN
# 371          3.0         Begumpet                                  NaN
#
#     Distance to Landmark  Price  Tax
# 284                  NaN  2,758  901
# 294              2.0 km   3,202  654
# 339                  NaN  3,761  451
# 371                  NaN  3,158  645

# %%
hotels.sort_values(by="Rating")
# Out:
#                                       Hotel Name  Rating Rating Description  \
# 142    OYO Home Fantasea Uthandi Near Juhu Beach     1.9               Poor
# 284                                     HOME@B11     2.3            Average
# 294                                Centaur Hotel     2.5            Average
# 371                                  The Manohar     2.7            Average
# 339                     Katriya Hotel and Towers     2.8            Average
# ..                                           ...     ...                ...
# 513                                  Joey's Nest     4.7          Excellent
# 428                           The Oberoi, Mumbai     4.7          Excellent
# 432                               Afra dormitory     4.8          Excellent
# 94   Four Seasons Hotel Bengaluru at Embassy One     4.8          Excellent
# 34          The Hosteller Bangalore Brigade Road     NaN                NaN
#
#      Reviews  Star Rating         Location  \
# ...
