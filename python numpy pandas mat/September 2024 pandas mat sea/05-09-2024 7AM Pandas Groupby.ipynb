# %%
import pandas as pd 
import numpy as np

# %%
cars = pd.read_csv('d:/data/usedcars.csv')
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
cars.color.value_counts()
# Out:
# color
# Black     35
# Silver    32
# Red       25
# Blue      17
# Gray      16
# White     16
# Green      5
# Yellow     3
# Gold       1
# Name: count, dtype: int64

# %%
cars.groupby("model").mean(numeric_only=True)[['price','mileage']]
# Out:
#               price       mileage
# model
# SE     12202.128205  46541.269231
# SEL    16109.260870  26238.913043
# SES    12694.102041  49089.448980

# %%
cars[['price','mileage','model']].groupby('model').describe()
# Out:
#       price                                                                   \
#       count          mean          std      min       25%      50%       75%
# model
# SE     78.0  12202.128205  2773.553342   3800.0  10865.75  12995.0  13994.25
# SEL    23.0  16109.260870  2475.443986  10995.0  14733.50  15980.0  16997.50
# SES    49.0  12694.102041  3059.196192   6200.0  10815.00  13742.0  14699.00
#
#                mileage                                                         \
#            max   count          mean           std     min       25%      50%
# model
# SE     17500.0    78.0  46541.269231  28298.437900  4867.0  29991.25  38964.5
# SEL    21992.0    23.0  26238.913043  15547.098203  7351.0  15305.00  25125.0
# SES    16995.0    49.0  49089.448980  26012.583031  9199.0  32655.00  38380.0
#
#
#            75%       max
# model
# SE     55124.5  151479.0
# SEL    33071.5   78264.0
# SES    64055.0  119720.0

# %%
cars[['price','mileage','model']].groupby('model').quantile(q=[0.25,0.5,0.75])
# Out:
#                price   mileage
# model
# SE    0.25  10865.75  29991.25
#       0.50  12995.00  38964.50
#       0.75  13994.25  55124.50
# SEL   0.25  14733.50  15305.00
#       0.50  15980.00  25125.00
#       0.75  16997.50  33071.50
# SES   0.25  10815.00  32655.00
#       0.50  13742.00  38380.00
#       0.75  14699.00  64055.00

# %%
insurance = pd.read_csv('d:/data/insurance.csv')
insurance.shape
# Out:
# (1338, 7)

# %%
insurance.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance[['age','bmi','charges','gender']].groupby('gender').mean()
# Out:
#               age        bmi       charges
# gender
# female  39.436090  30.370211  12575.123638
# male    38.980684  30.953098  13957.455827

# %%
insurance[['age','bmi','charges','smoker']].groupby('smoker').describe()['age']
# Out:
#          count       mean        std   min    25%   50%   75%   max
# smoker
# no      1064.0  39.385338  14.083410  18.0  26.75  40.0  52.0  64.0
# yes      274.0  38.514599  13.923186  18.0  27.00  38.0  49.0  64.0

# %%
insurance[['age','bmi','charges','smoker']].groupby('smoker').describe()['bmi']
# Out:
#          count       mean       std     min       25%      50%    75%    max
# smoker
# no      1064.0  30.651795  6.043111  15.960  26.31500  30.3525  34.43  53.13
# yes      274.0  30.708449  6.318644  17.195  26.08375  30.4475  35.20  52.58

# %%
insurance[['age','bmi','charges','smoker']].groupby('smoker').describe()['charges']
# Out:
#          count          mean           std         min           25%  \
# smoker
# no      1064.0   8434.268298   5993.781819   1121.8739   3986.438700
# yes      274.0  32050.231832  11541.547176  12829.4551  20826.244213
#
#                 50%           75%          max
# smoker
# no       7345.40530  11362.887050  36910.60803
# yes     34456.34845  41019.207275  63770.42801

# %%
credit = pd.read_csv('d:/data/credit.csv')
credit.shape
# Out:
# (1000, 21)

# %%
credit.head()
# Out:
#   checking_balance  months_loan_duration credit_history    purpose  amount  \
# 0           < 0 DM                     6       critical   radio/tv    1169
# 1       1 - 200 DM                    48         repaid   radio/tv    5951
# 2          unknown                    12       critical  education    2096
# 3           < 0 DM                    42         repaid  furniture    7882
# 4           < 0 DM                    24        delayed  car (new)    4870
#
#   savings_balance employment_length  installment_rate personal_status  \
# 0         unknown           > 7 yrs                 4     single male
# 1        < 100 DM         1 - 4 yrs                 2          female
# 2        < 100 DM         4 - 7 yrs                 2     single male
# 3        < 100 DM         4 - 7 yrs                 2     single male
# 4        < 100 DM         1 - 4 yrs                 3     single male
#
#   other_debtors  ...                  property age  installment_plan  \
# ...

# %%
credit[['purpose','amount']].groupby('purpose').mean()
# Out:
#                           amount
# purpose
# business             4158.041237
# car (new)            3063.025641
# car (used)           5370.223301
# domestic appliances  1498.000000
# education            3180.400000
# furniture            3066.988950
# others               8209.333333
# radio/tv             2487.653571
# repairs              2728.090909
# retraining           1205.888889

# %%
cars.groupby(['model','color']).mean(numeric_only=True)
# Out:
#                      year         price        mileage
# model color
# SE    Black   2009.578947  13345.210526   34167.421053
#       Blue    2009.222222  13196.444444   35695.000000
#       Gold    2009.000000  10955.000000   40180.000000
#       Gray    2009.142857  12816.571429   40932.000000
#       Green   2007.000000  10900.000000   40483.500000
#       Red     2006.666667  10829.083333   65958.083333
#       Silver  2008.000000  11444.818182   50097.363636
#       White   2009.142857  12459.071429   48364.142857
#       Yellow  2001.000000   4899.000000  151479.000000
# SEL   Black   2010.333333  15290.333333   25634.666667
#       Blue    2010.333333  16226.666667   19691.333333
#       Gray    2010.000000  15592.600000   33175.600000
#       Green   2011.000000  16950.000000    9388.000000
#       Red     2009.000000  13969.500000   39381.500000
#       Silver  2010.000000  16448.285714   23733.142857
#       White   2010.000000  15980.000000   39943.000000
# ...

# %%
df1 = credit[['purpose','personal_status','amount']].groupby(['purpose','personal_status']).describe()
df1
# Out:
#                                     amount                             \
#                                      count          mean          std
# purpose             personal_status
# business            divorced male     10.0   4142.700000  2840.912179
#                     female            19.0   3195.421053  2428.716037
#                     married male       9.0   2323.444444  1777.269050
#                     single male       59.0   4750.491525  3547.188694
# car (new)           divorced male     10.0   2843.800000  2393.082986
#                     female            70.0   2531.557143  2239.280627
#                     married male      20.0   1632.050000  1209.099512
#                     single male      134.0   3570.597015  3385.133320
# car (used)          divorced male      3.0   6534.000000  2710.602701
#                     female            24.0   5814.375000  3375.829442
#                     married male       6.0   4743.333333  3012.105089
# ...

# %%
df1.loc['business']
# Out:
#                 amount                                                     \
#                  count         mean          std     min      25%     50%
# personal_status
# divorced male     10.0  4142.700000  2840.912179  1275.0  1986.75  3340.5
# female            19.0  3195.421053  2428.716037   609.0  1300.00  2528.0
# married male       9.0  2323.444444  1777.269050   907.0  1391.00  1887.0
# single male       59.0  4750.491525  3547.188694  1037.0  2350.50  3844.0
#
#
#                     75%      max
# personal_status
# divorced male    5830.5   9572.0
# female           4294.0   8318.0
# married male     2169.0   6568.0
# single male      6023.0  15945.0

# %%
df1.loc['radio/tv']
# Out:
#                 amount                                                     \
#                  count         mean          std     min      25%     50%
# personal_status
# divorced male      7.0  2138.142857   826.963407  1126.0  1548.00  2149.0
# female            85.0  2400.517647  1886.589930   385.0  1240.00  1715.0
# married male      42.0  1920.976190  1593.566555   426.0  1031.25  1443.0
# single male      146.0  2718.157534  2304.143679   338.0  1346.25  2109.0
#
#
#                     75%      max
# personal_status
# divorced male    2680.5   3235.0
# female           2991.0  10144.0
# married male     2057.0   7166.0
# single male      3098.0  15653.0

# %%
credit.purpose.value_counts()
# Out:
# purpose
# radio/tv               280
# car (new)              234
# furniture              181
# car (used)             103
# business                97
# education               50
# repairs                 22
# domestic appliances     12
# others                  12
# retraining               9
# Name: count, dtype: int64

# %%
cars[['model','price','mileage']].groupby('model').describe()
# Out:
#       price                                                                   \
#       count          mean          std      min       25%      50%       75%
# model
# SE     78.0  12202.128205  2773.553342   3800.0  10865.75  12995.0  13994.25
# SEL    23.0  16109.260870  2475.443986  10995.0  14733.50  15980.0  16997.50
# SES    49.0  12694.102041  3059.196192   6200.0  10815.00  13742.0  14699.00
#
#                mileage                                                         \
#            max   count          mean           std     min       25%      50%
# model
# SE     17500.0    78.0  46541.269231  28298.437900  4867.0  29991.25  38964.5
# SEL    21992.0    23.0  26238.913043  15547.098203  7351.0  15305.00  25125.0
# SES    16995.0    49.0  49089.448980  26012.583031  9199.0  32655.00  38380.0
#
#
#            75%       max
# model
# SE     55124.5  151479.0
# SEL    33071.5   78264.0
# SES    64055.0  119720.0

# %%
cars.pivot_table
