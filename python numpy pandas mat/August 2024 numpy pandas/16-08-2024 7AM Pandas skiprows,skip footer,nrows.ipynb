# %%
import pandas as pd

# %%
schools = pd.read_csv('c:/data/Districtwise_SchoolData.csv',header=3)
schools
# Out:
#       Statecd                                        State Name   distcd  \
# 0          35  ANDAMAN & NICOBAR ISLANDS                     ...    3501
# 1          35  ANDAMAN & NICOBAR ISLANDS                     ...    3503
# 2          35  ANDAMAN & NICOBAR ISLANDS                     ...    3502
# 3          28  ANDHRA PRADESH                                ...    2801
# 4          28  ANDHRA PRADESH                                ...    2822
# ...       ...                                                ...     ...
# 1319       19  WEST BENGAL                                   ...    1919
# 1320       19  WEST BENGAL                                   ...    1914
# 1321       19  WEST BENGAL                                   ...    1921
# 1322       19  WEST BENGAL                                   ...    1918
# 1323       19  WEST BENGAL                                   ...    1904
#
#                                                distname  ac_year  schgovt1  \
# ...

# %%
messy = pd.read_csv('c:/data/messydata.csv',sep=' ',skiprows=[0,1,3,6,9],header=0)
messy
# Out:
#      name     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0     IBM  156.08  160.01  159.81  165.22  172.25  167.15  164.75  152.77
# 1    MSFT   45.51   43.08   42.13   43.47   47.53   45.96   45.61   45.51
# 2  GOOGLE  512.42  537.99  559.72  540.50  535.24  532.92  590.09  636.84
# 3   APPLE  110.64  125.43  125.97  127.29  128.76  127.81  125.34  113.39
#
#       Sep     Oct     Nov     Dec,
# 0  145.36  146.11  137.21  137.96,
# 1   43.56   48.70   53.88   55.40,
# 2  617.93  663.59  735.39  755.35,
# 3  112.80  113.36  118.16  111.73,

# %%
messy = pd.read_csv('c:/data/messydata.csv',sep=' ',skiprows=2,header=0,comment='@')
messy
# Out:
#      name     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0     IBM  156.08  160.01  159.81  165.22  172.25  167.15  164.75  152.77
# 1    MSFT   45.51   43.08   42.13   43.47   47.53   45.96   45.61   45.51
# 2  GOOGLE  512.42  537.99  559.72  540.50  535.24  532.92  590.09  636.84
# 3   APPLE  110.64  125.43  125.97  127.29  128.76  127.81  125.34  113.39
#
#       Sep     Oct     Nov     Dec,
# 0  145.36  146.11  137.21  137.96,
# 1   43.56   48.70   53.88   55.40,
# 2  617.93  663.59  735.39  755.35,
# 3  112.80  113.36  118.16  111.73,

# %%
messy = pd.read_csv('c:/data/messydata.csv',sep=' ',comment='@',header=2)
messy
# Out:
#      name     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0     IBM  156.08  160.01  159.81  165.22  172.25  167.15  164.75  152.77
# 1    MSFT   45.51   43.08   42.13   43.47   47.53   45.96   45.61   45.51
# 2  GOOGLE  512.42  537.99  559.72  540.50  535.24  532.92  590.09  636.84
# 3   APPLE  110.64  125.43  125.97  127.29  128.76  127.81  125.34  113.39
#
#       Sep     Oct     Nov     Dec,
# 0  145.36  146.11  137.21  137.96,
# 1   43.56   48.70   53.88   55.40,
# 2  617.93  663.59  735.39  755.35,
# 3  112.80  113.36  118.16  111.73,

# %%
messy = pd.read_csv('c:/data/messydata.csv',sep=' ',skiprows=[3,6],header=2,skipfooter=1,engine='python')
messy
# Out:
#      name     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0     IBM  156.08  160.01  159.81  165.22  172.25  167.15  164.75  152.77
# 1    MSFT   45.51   43.08   42.13   43.47   47.53   45.96   45.61   45.51
# 2  GOOGLE  512.42  537.99  559.72  540.50  535.24  532.92  590.09  636.84
# 3   APPLE  110.64  125.43  125.97  127.29  128.76  127.81  125.34  113.39
#
#       Sep     Oct     Nov     Dec,
# 0  145.36  146.11  137.21  137.96,
# 1   43.56   48.70   53.88   55.40,
# 2  617.93  663.59  735.39  755.35,
# 3  112.80  113.36  118.16  111.73,

# %%
airquality = pd.read_csv('c:/data/AirQuality.csv',sep=';',decimal=',',skipfooter=114,engine='python')
airquality
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6         1360       150      11.9
# 1     10/03/2004  19.00.00     2.0         1292       112       9.4
# 2     10/03/2004  20.00.00     2.2         1402        88       9.0
# 3     10/03/2004  21.00.00     2.2         1376        80       9.2
# 4     10/03/2004  22.00.00     1.6         1272        51       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1         1314      -200      13.5
# 9353  04/04/2005  11.00.00     2.4         1163      -200      11.4
# 9354  04/04/2005  12.00.00     2.4         1142      -200      12.4
# 9355  04/04/2005  13.00.00     2.1         1003      -200       9.5
# 9356  04/04/2005  14.00.00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
cars = pd.read_csv('c:/data/usedcars.csv',nrows=10)
cars
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO
# 6  2011   SEL  17000    27393    Blue         AUTO
# 7  2010   SEL  16995    21026  Silver         AUTO
# 8  2011   SES  16995    32655  Silver         AUTO
# 9  2010   SES  16995    36116  Silver         AUTO
