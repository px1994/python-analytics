# %%
import pandas as pd

# %%
iris = pd.read_csv('c:/data/iris.csv',
                   names=['sepal_length','sepal_width','petal_length','petal_width','species'],
                   converters={"species":lambda x:x.split("-")[1]})
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.set_index(keys="species",drop=True,append=False,inplace=True)

# %%
iris.head()
# Out:
#          sepal_length  sepal_width  petal_length  petal_width
# species
# setosa            5.1          3.5           1.4          0.2
# setosa            4.9          3.0           1.4          0.2
# setosa            4.7          3.2           1.3          0.2
# setosa            4.6          3.1           1.5          0.2
# setosa            5.0          3.6           1.4          0.2

# %%
cars = pd.read_csv('c:/data/usedcars.csv',index_col="model")
cars.head()
# Out:
#        year  price  mileage   color transmission
# model
# SEL    2011  21992     7413  Yellow         AUTO
# SEL    2011  20995    10926    Gray         AUTO
# SEL    2011  19995     7351  Silver         AUTO
# SEL    2011  17809    11613    Gray         AUTO
# SE     2012  17500     8367   White         AUTO

# %%
cars.set_index(keys='color',drop=True,append=False,inplace=True)

# %%
cars
# Out:
#         year  price  mileage transmission
# color
# Yellow  2011  21992     7413         AUTO
# Gray    2011  20995    10926         AUTO
# Silver  2011  19995     7351         AUTO
# Gray    2011  17809    11613         AUTO
# White   2012  17500     8367         AUTO
# ...      ...    ...      ...          ...
# Silver  2006   6200    95000         AUTO
# Red     2002   5995    87003         AUTO
# Red     2000   5980    96841         AUTO
# Yellow  2001   4899   151479         AUTO
# Red     2000   3800   109259         AUTO
#
# [150 rows x 4 columns]

# %%
cars.set_index(keys='year',drop=True,append=False,inplace=True)

# %%
cars
# Out:
#       price  mileage transmission
# year
# 2011  21992     7413         AUTO
# 2011  20995    10926         AUTO
# 2011  19995     7351         AUTO
# 2011  17809    11613         AUTO
# 2012  17500     8367         AUTO
# ...     ...      ...          ...
# 2006   6200    95000         AUTO
# 2002   5995    87003         AUTO
# 2000   5980    96841         AUTO
# 2001   4899   151479         AUTO
# 2000   3800   109259         AUTO
#
# [150 rows x 3 columns]

# %%
cars = pd.read_csv('c:/data/usedcars.csv')
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
cars.set_index(keys="year",drop=True,append=False,inplace=True)
cars
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27180\88244075.py in ?()
# ----> 1 cars.set_index(keys="year",drop=True,append=False,inplace=True)
#       2 cars
#
# C:\vamsi\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['year'] are in the columns"

# %%
cars.head()
# Out:
#       price  mileage transmission
# year
# 2011  21992     7413         AUTO
# 2011  20995    10926         AUTO
# 2011  19995     7351         AUTO
# 2011  17809    11613         AUTO
# 2012  17500     8367         AUTO

# %%
cars.index
# Out:
# Index([2011, 2011, 2011, 2011, 2012, 2010, 2011, 2010, 2011, 2010,
#        ...
#        2004, 2007, 2000, 2004, 2004, 2006, 2002, 2000, 2001, 2000],
#       dtype='int64', name='year', length=150)

# %%
cars.reset_index(level='year',drop=False,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 cars.reset_index(level='year',drop=False,inplace=True)
#
# File C:\vamsi\anaconda3\Lib\site-packages\pandas\core\frame.py:6425, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6423 if not isinstance(level, (tuple, list)):
#    6424     level = [level]
# -> 6425 level = [self.index._get_level_number(lev) for lev in level]
#    6426 if len(level) < self.index.nlevels:
#    6427     new_index = self.index.droplevel(level)
#
# File C:\vamsi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2017, in Index._get_level_number(self, level)
#    2016 def _get_level_number(self, level) -> int:
# -> 2017     self._validate_index_level(level)
#    2018     return 0
#
# ...

# %%
cars = pd.read_csv('c:/data/usedcars.csv')
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
cars.set_index(keys='model',drop=False,append=True,inplace=True)
cars.head()
# Out:
#                                                                                year  \
# model model model model model model model model model model model model model
# SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL    2011
#                                                                         SEL    2011
#                                                                         SEL    2011
#                                                                         SEL    2011
# SE    SE    SE    SE    SE    SE    SE    SE    SE    SE    SE    SE    SE     2012
#
#                                                                               model  \
# model model model model model model model model model model model model model
# SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL   SEL     SEL
#                                                                         SEL     SEL
# ...

# %%
cars[cars.model=='SES']
# Out:
#      year model  price  mileage   color transmission
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# 13   2010   SES  16950    32058     Red         AUTO
# 15   2011   SES  15999    16368    Blue         AUTO
# 17   2010   SES  15995    36049  Silver         AUTO
# 20   2010   SES  15988    16035  Silver       MANUAL
# 28   2010   SES  15298    22029    Gray         AUTO
# 30   2010   SES  14999    36306     Red         AUTO
# 34   2009   SES  14992    24030     Red         AUTO
# 40   2010   SES  14761    44813   Black         AUTO
# 41   2010   SES  14699    36469    Gray         AUTO
# 42   2010   SES  14677    22143   Black       MANUAL
# 43   2009   SES  14549    34046  Silver         AUTO
# 45   2010   SES  14495    35894  Silver         AUTO
# 51   2010   SES  14275    35318   Black         AUTO
# 52   2010   SES  14000    24929  Silver         AUTO
# ...

# %%
cars[cars.price>20000]
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO

# %%
cars[(cars.model=='SE') & (cars.color=='White')]
# Out:
#      year model  price  mileage  color transmission
# 4    2012    SE  17500     8367  White         AUTO
# 14   2011    SE  16000    15367  White         AUTO
# 36   2011    SE  14989    23967  White         AUTO
# 38   2010    SE  14900    28955  White         AUTO
# 39   2010    SE  14893    11165  White         AUTO
# 68   2009    SE  13888    50533  White         AUTO
# 85   2010    SE  12995    40058  White       MANUAL
# 99   2008    SE  12500    45996  White       MANUAL
# 100  2009    SE  12500    54988  White       MANUAL
# 125  2008    SE   9995    95364  White         AUTO
# 126  2008    SE   9992    74109  White         AUTO
# 131  2006    SE   8800    71331  White         AUTO
# 134  2009    SE   8480    70036  White       MANUAL
# 141  2007    SE   6995    86862  White         AUTO

# %%
cars.query("model in('SE','SEL') and color=='Black'")
# Out:
#      year model  price  mileage  color transmission
# 10   2010   SEL  16995    40539  Black         AUTO
# 23   2010   SEL  15889    24920  Black         AUTO
# 26   2010    SE  15499     7784  Black         AUTO
# 27   2010    SE  15499    35636  Black         AUTO
# 31   2009    SE  14995    34419  Black       MANUAL
# 32   2011    SE  14992     4867  Black         AUTO
# 33   2011   SEL  14992    18948  Black         AUTO
# 35   2010   SEL  14990    33036  Black         AUTO
# 46   2010    SE  14495    38275  Black         AUTO
# 50   2010    SE  14299    36447  Black         AUTO
# 54   2010    SE  13997    15167  Black       MANUAL
# 56   2010    SE  13995    20278  Black       MANUAL
# 64   2009    SE  13950     9450  Black         AUTO
# 65   2010    SE  13950    31414  Black         AUTO
# 78   2010    SE  13383    34503  Black         AUTO
# 83   2010    SE  12995    21325  Black         AUTO
# 84   2010    SE  12995    32743  Black       MANUAL
# ...
