# %%
import pandas as pd

# %%
cars = pd.read_csv('c:/data/usedcars.csv')
cars.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
cars[cars.model=='SE']
# Out:
#      year model  price  mileage   color transmission
# 4    2012    SE  17500     8367   White         AUTO
# 14   2011    SE  16000    15367   White         AUTO
# 22   2011    SE  15899    36685  Silver         AUTO
# 25   2010    SE  15500    29338    Blue         AUTO
# 26   2010    SE  15499     7784   Black         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 142  2000    SE   6980    60161   Green         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [78 rows x 6 columns]

# %%
cars.query("model in('SES','SE')")
# Out:
#      year model  price  mileage   color transmission
# 4    2012    SE  17500     8367   White         AUTO
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# 13   2010   SES  16950    32058     Red         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [126 rows x 6 columns]

# %%
cars.set_index(keys="model",inplace=True)
cars.head()
# Out:
#        year  price  mileage   color transmission
# model
# SEL    2011  21992     7413  Yellow         AUTO
# SEL    2011  20995    10926    Gray         AUTO
# SEL    2011  19995     7351  Silver         AUTO
# SEL    2011  17809    11613    Gray         AUTO
# SE     2012  17500     8367   White         AUTO

# %%
cars.columns
# Out:
# Index(['year', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
cars.loc[["SES",'SE'],["price",'mileage','color']]
# Out:
#        price  mileage   color
# model
# SES    16995    32655  Silver
# SES    16995    36116  Silver
# SES    16992     9199  Silver
# SES    16950    32058     Red
# SES    15999    16368    Blue
# ...      ...      ...     ...
# SE      6980    60161   Green
# SE      5995    87003     Red
# SE      5980    96841     Red
# SE      4899   151479  Yellow
# SE      3800   109259     Red
#
# [126 rows x 3 columns]

# %%
wine_red = pd.read_csv('c:/data/winequality-red.csv',sep=';',index_col="quality")
wine_red.head()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 5                  7.4              0.70         0.00             1.9
# 5                  7.8              0.88         0.00             2.6
# 5                  7.8              0.76         0.04             2.3
# 6                 11.2              0.28         0.56             1.9
# 5                  7.4              0.70         0.00             1.9
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 5            0.076                 11.0                  34.0   0.9978  3.51
# 5            0.098                 25.0                  67.0   0.9968  3.20
# 5            0.092                 15.0                  54.0   0.9970  3.26
# 6            0.075                 17.0                  60.0   0.9980  3.16
# 5            0.076                 11.0                  34.0   0.9978  3.51
#
#          sulphates  alcohol
# quality
# ...

# %%
wine_red.loc[[6,5],"fixed acidity":"chlorides"]
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 6                 11.2             0.280         0.56             1.9
# 6                  7.9             0.320         0.51             1.8
# 6                  8.9             0.220         0.48             1.8
# 6                  6.9             0.400         0.14             2.4
# 6                  7.8             0.645         0.00             2.0
# ...                ...               ...          ...             ...
# 5                  6.1             0.715         0.10             2.6
# 5                  6.2             0.460         0.29             2.1
# 5                  6.6             0.725         0.20             7.8
# 5                  6.2             0.600         0.08             2.0
# 5                  5.9             0.645         0.12             2.0
#
#          chlorides
# quality
# 6            0.075
# 6            0.341
# 6            0.077
# 6            0.085
# ...

# %%
cars = pd.read_csv('c:/data/usedcars.csv')
cars.head(10)
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO
# 6  2011   SEL  17000    27393    Blue         AUTO
# 7  2010   SEL  16995    21026  Silver         AUTO
# 8  2011   SES  16995    32655  Silver         AUTO
# 9  2010   SES  16995    36116  Silver         AUTO

# %%
cars_new = cars.sample(40)
cars_new
# Out:
#      year model  price  mileage   color transmission
# 65   2010    SE  13950    31414   Black         AUTO
# 10   2010   SEL  16995    40539   Black         AUTO
# 83   2010    SE  12995    21325   Black         AUTO
# 104  2009   SES  11984    59048   Black         AUTO
# 54   2010    SE  13997    15167   Black       MANUAL
# 142  2000    SE   6980    60161   Green         AUTO
# 34   2009   SES  14992    24030     Red         AUTO
# 137  2006   SES   7995    97987     Red         AUTO
# 75   2009   SEL  13584    43369     Red         AUTO
# 109  2008   SES  11495    82221  Silver         AUTO
# 115  2008    SE  10955    39643    Gray         AUTO
# 119  2007    SE  10770    72937  Silver       MANUAL
# 125  2008    SE   9995    95364   White         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# 47   2010    SE  14480    24855    Blue         AUTO
# 37   2010    SE  14906    37905  Silver         AUTO
# 136  2006   SES   7995    35000   Black       MANUAL
# ...

# %%
cars.iloc[10:30]
# Out:
#     year model  price  mileage   color transmission
# 10  2010   SEL  16995    40539   Black         AUTO
# 11  2011   SES  16992     9199  Silver         AUTO
# 12  2011   SEL  16950     9388   Green         AUTO
# 13  2010   SES  16950    32058     Red         AUTO
# 14  2011    SE  16000    15367   White         AUTO
# 15  2011   SES  15999    16368    Blue         AUTO
# 16  2010   SEL  15999    19926  Silver         AUTO
# 17  2010   SES  15995    36049  Silver         AUTO
# 18  2011   SEL  15992    11662    Blue         AUTO
# 19  2011   SEL  15992    32069  Silver         AUTO
# 20  2010   SES  15988    16035  Silver       MANUAL
# 21  2010   SEL  15980    39943   White         AUTO
# 22  2011    SE  15899    36685  Silver         AUTO
# 23  2010   SEL  15889    24920   Black         AUTO
# 24  2009   SEL  15688    20019    Blue         AUTO
# 25  2010    SE  15500    29338    Blue         AUTO
# 26  2010    SE  15499     7784   Black         AUTO
# ...

# %%
cars_new.iloc[10:34].shape
# Out:
# (24, 6)

# %%
cars_new.loc[10:34].shape
# Out:
# (6, 6)

# %%
cars.iloc[1:10]
# Out:
#    year model  price  mileage   color transmission
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO
# 6  2011   SEL  17000    27393    Blue         AUTO
# 7  2010   SEL  16995    21026  Silver         AUTO
# 8  2011   SES  16995    32655  Silver         AUTO
# 9  2010   SES  16995    36116  Silver         AUTO

# %%
cars.loc[1:10]
# Out:
#     year model  price  mileage   color transmission
# 1   2011   SEL  20995    10926    Gray         AUTO
# 2   2011   SEL  19995     7351  Silver         AUTO
# 3   2011   SEL  17809    11613    Gray         AUTO
# 4   2012    SE  17500     8367   White         AUTO
# 5   2010   SEL  17495    25125  Silver         AUTO
# 6   2011   SEL  17000    27393    Blue         AUTO
# 7   2010   SEL  16995    21026  Silver         AUTO
# 8   2011   SES  16995    32655  Silver         AUTO
# 9   2010   SES  16995    36116  Silver         AUTO
# 10  2010   SEL  16995    40539   Black         AUTO

# %%
cars_new.iloc[:5]
# Out:
#      year model  price  mileage  color transmission
# 65   2010    SE  13950    31414  Black         AUTO
# 10   2010   SEL  16995    40539  Black         AUTO
# 83   2010    SE  12995    21325  Black         AUTO
# 104  2009   SES  11984    59048  Black         AUTO
# 54   2010    SE  13997    15167  Black       MANUAL

# %%
cars_new.loc[65:54]
# Out:
#      year model  price  mileage  color transmission
# 65   2010    SE  13950    31414  Black         AUTO
# 10   2010   SEL  16995    40539  Black         AUTO
# 83   2010    SE  12995    21325  Black         AUTO
# 104  2009   SES  11984    59048  Black         AUTO
# 54   2010    SE  13997    15167  Black       MANUAL

# %%
cars.set_index(keys="color",inplace=True)

# %%
cars
# Out:
#         year model  price  mileage transmission
# color
# Yellow  2011   SEL  21992     7413         AUTO
# Gray    2011   SEL  20995    10926         AUTO
# Silver  2011   SEL  19995     7351         AUTO
# Gray    2011   SEL  17809    11613         AUTO
# White   2012    SE  17500     8367         AUTO
# ...      ...   ...    ...      ...          ...
# Silver  2006   SES   6200    95000         AUTO
# Red     2002    SE   5995    87003         AUTO
# Red     2000    SE   5980    96841         AUTO
# Yellow  2001    SE   4899   151479         AUTO
# Red     2000    SE   3800   109259         AUTO
#
# [150 rows x 5 columns]

# %%
cars.loc[['Blue','Black']]
# Out:
#        year model  price  mileage transmission
# color
# Blue   2011   SEL  17000    27393         AUTO
# Blue   2011   SES  15999    16368         AUTO
# Blue   2011   SEL  15992    11662         AUTO
# Blue   2009   SEL  15688    20019         AUTO
# Blue   2010    SE  15500    29338         AUTO
# Blue   2010    SE  14480    24855         AUTO
# Blue   2010    SE  13950    37185         AUTO
# Blue   2009    SE  13845    36713         AUTO
# Blue   2010    SE  13350    16573         AUTO
# Blue   2009   SES  12999    32403         AUTO
# Blue   2009    SE  12998    34846         AUTO
# Blue   2009    SE  12995    42325         AUTO
# Blue   2008   SES  12704    36323         AUTO
# Blue   2009   SES  12595    39211         AUTO
# Blue   2009    SE  11999    36124         AUTO
# Blue   2005   SES  10995    69415         AUTO
# Blue   2007    SE   9651    63296         AUTO
# Black  2010   SEL  16995    40539         AUTO
# Black  2010   SEL  15889    24920         AUTO
# ...

# %%
wisc = pd.read_csv('c:/data/wisc_bc_data.csv',index_col="id")
wisc.shape
# Out:
# (569, 31)

# %%
wisc.head(10)
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# 843786           M        12.45         15.70           82.57      477.1
# 844359           M        18.25         19.98          119.60     1040.0
# 84458202         M        13.71         20.83           90.20      577.9
# 844981           M        13.00         21.82           87.50      519.8
# 84501001         M        12.46         24.04           83.97      475.9
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760         0.30010
# ...

# %%
wisc.iloc[842302:844359]
# Out:
# Empty DataFrame
# Columns: [diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 31 columns]

# %%
wisc.loc[842302:844359]
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# 843786           M        12.45         15.70           82.57      477.1
# 844359           M        18.25         19.98          119.60     1040.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
# ...
