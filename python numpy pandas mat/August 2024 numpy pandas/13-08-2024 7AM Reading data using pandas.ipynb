# %%
import numpy as np 
import pandas as pd

# %%
marks = np.random.randint(70,91,(3,5))
marks
# Out:
# array([[75, 89, 89, 76, 89],
#        [76, 75, 76, 78, 86],
#        [87, 77, 89, 81, 83]])

# %%
df = pd.DataFrame(marks,columns=['x','y','z','a','b'],index=['maths','physics','chemistry'])
df.shape
# Out:
# (3, 5)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
cars= pd.read_csv('c:/data/usedcars.csv',sep=',')
cars.shape
# Out:
# (150, 6)

# %%
cars
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
wine_red = pd.read_csv('c:/data/winequality-red.csv',delimiter=";")
wine_red.shape
# Out:
# (1599, 12)

# %%
wine_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_white = pd.read_csv('c:/data/winequality-white.csv',delimiter=";")
wine_white.shape
# Out:
# (4898, 12)

# %%
wine_white.shape
# Out:
# (4898, 12)
