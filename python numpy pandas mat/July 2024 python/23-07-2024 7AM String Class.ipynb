# %%
s='abcd'
s.isalpha(),s.isdigit(),s.isalnum()
# Out:
# (True, False, True)

# %%
s='1234'
s.isalpha(),s.isdigit(),s.isalnum()
# Out:
# (False, True, True)

# %%
s='abcd1234'
s.isalpha(),s.isdigit(),s.isalnum()
# Out:
# (False, False, True)

# %%
s='abcd#1234'
s.isalpha(),s.isdigit(),s.isalnum(),s.isprintable()
# Out:
# (False, False, False, True)

# %%
s='abcd\t1234'
s.isalpha(),s.isdigit(),s.isalnum(),s.isprintable()
# Out:
# (False, False, False, False)

# %%
s='hello world'
s[5].isspace()
# Out:
# True

# %%
sms = 'your OTP for online Transaction is 847847 Please do not share this OTP with anyone'
otp = [w for w in sms.split() if w.isdigit()]
otp
# Out:
# ['847847']

# %%
sms = 'Please contact me tomorrow at 10AM on my contact number 8347345934'
otp = [w for w in sms.split() if not w.isalpha()]
otp
# Out:
# ['10AM', '8347345934']

# %%
s = 'welcome to python training python is a general purpose language'
vowels_count={}
for i in ['a','e','i','o','u']:
    vowels_count[i]=s.count(i)
vowels_count
# Out:
# {'a': 5, 'e': 6, 'i': 3, 'o': 5, 'u': 2}

# %%
s='welcome'
s.index('e'),s.index('e',4),s.index('e',2,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 s='welcome'
# ----> 2 s.index('e'),s.index('e',4),s.index('e',2,5)
#
# ValueError: substring not found

# %%
s='welcome'
s.find('e'),s.find('e',4),s.find('e',2,5)
# Out:
# (1, 6, -1)

# %%
s='$1245.00000'
s.removeprefix('$'),s.removesuffix('00')
# Out:
# ('1245.00000', '$1245.000')

# %%
s='$1245.00000'
s.lstrip('$'),s.rstrip('.0')
# Out:
# ('1245.00000', '$1245')

# %%
s = '   welcome    '
s,s.lstrip(),s.rstrip(),s.strip()
# Out:
# ('   welcome    ', 'welcome    ', '   welcome', 'welcome')

# %%
s='###$#welcome#####'
s.strip('$#')
# Out:
# 'welcome'

# %%
s='welcome'
print(s)
print(s.rjust(15,'#'))
print(s.center(15,'!'))
print(s.ljust(15,'*'))
# Out:
# welcome
# ########welcome
# !!!!welcome!!!!
# welcome********

# %%
s='welcome'
s.replace('e','x',2)
# Out:
# 'wxlcomx'

# %%
s=".567"
print(s,s.zfill(5))
# Out:
# .567 0.567

# %%
s='WelCOme'
s.casefold()
# Out:
# 'welcome'

# %%
s='welcome to python training python is general purpose language'
s.rpartition(' ')
# Out:
# ('welcome to python training python is general purpose', ' ', 'language')

# %%
s.split()
# Out:
# ['welcome',
#  'to',
#  'python',
#  'training',
#  'python',
#  'is',
#  'general',
#  'purpose',
#  'language']
