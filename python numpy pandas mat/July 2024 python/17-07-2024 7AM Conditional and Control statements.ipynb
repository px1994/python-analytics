# %%
n = int(input('Enter a Number:'))
print(n,type(n))
# Out:
# Enter a Number:10
# 10 <class 'int'>

# %%
n = int(input('Enter a Number:'))
if n%2==0:
    print('Even Number')
else:
    print('Odd Number')
print('End of the programme')
# Out:
# Enter a Number:11
# Odd Number
# End of the programme

# %%
a=int(input('Enter a number:'))
b=int(input('Enter b number:'))
if a>b:
    print('a is greater')
elif b>a:
    print('b is greater')
else:
    print('both are equal')
print('End of the programme')
# Out:
# Enter a number:10
# Enter b number:10
# both are equal
# End of the programme

# %%
x=[20,"hello",True,30.45,False]
for i in x:
    print(i,type(i))
# Out:
# 20 <class 'int'>
# hello <class 'str'>
# True <class 'bool'>
# 30.45 <class 'float'>
# False <class 'bool'>

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in "welcome":
    print(i)
# Out:
# w
# e
# l
# c
# o
# m
# e

# %%
for i in {20,30,10,40,50,20}:
    print(i)
# Out:
# 40
# 10
# 50
# 20
# 30

# %%
d={"a":10,"b":20,"c":30}
for i in d.items() :
    print(i)
# Out:
# ('a', 10)
# ('b', 20)
# ('c', 30)
