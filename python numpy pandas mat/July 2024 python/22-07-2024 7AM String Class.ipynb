# %%
s='wELComE to pYthoN trAiNing. pythoN is geNeraL purPose lAnguAgE'

# %%
print('Actual String:',s)
print('Upper Case:',s.upper())
print('Lower Case:',s.lower())
print('capitalize:',s.capitalize())
print('title:',s.title())
print('swap case:',s.swapcase())
# Out:
# Actual String: wELComE to pYthoN trAiNing. pythoN is geNeraL purPose lAnguAgE
# Upper Case: WELCOME TO PYTHON TRAINING. PYTHON IS GENERAL PURPOSE LANGUAGE
# Lower Case: welcome to python training. python is general purpose language
# capitalize: Welcome to python training. python is general purpose language
# title: Welcome To Python Training. Python Is General Purpose Language
# swap case: WelcOMe TO PyTHOn TRaInING. PYTHOn IS GEnERAl PURpOSE LaNGUaGe
# wELComE to pYthoN trAiNing. pythoN is geNeraL purPose lAnguAgE

# %%
s1='WELCOME'
s1.isupper(),s1.islower(),s1.istitle()
# Out:
# (True, False, False)

# %%
s1='welcome'
s1.isupper(),s1.islower(),s1.istitle()
# Out:
# (False, True, False)

# %%
s1='Welcome'
s1.isupper(),s1.islower(),s1.istitle()
# Out:
# (False, False, True)

# %%
s1='welcomE'
s1.isupper(),s1.islower(),s1.istitle()
# Out:
# (False, False, False)

# %%
s2='welcome'
s2.startswith('w'),s2.endswith('e'),s2.startswith('a'),s2.endswith('me')
# Out:
# (True, True, False, True)

# %%
s='wELComE to pYthoN trAiNing. pythoN is geNeraL purPose lAnguAgE'
s.split(" "),s.istitle()
# Out:
# (['wELComE',
#   'to',
#   'pYthoN',
#   'trAiNing.',
#   'pythoN',
#   'is',
#   'geNeraL',
#   'purPose',
#   'lAnguAgE'],
#  False)

# %%
s1='python#numpy#Machine Learning#Data science#NLP'
s1.split('#')
# Out:
# ['python', 'numpy', 'Machine Learning', 'Data science', 'NLP']

# %%
s1='welcome to python training'
s1.split(maxsplit=2),s1.split(maxsplit=1)
# Out:
# (['welcome', 'to', 'python training'], ['welcome', 'to python training'])

# %%
s1='welcome to python training'
s1.rsplit(),s1.split()
# Out:
# (['welcome', 'to', 'python', 'training'],
#  ['welcome', 'to', 'python', 'training'])

# %%
s1='welcome to python training'
s1.rsplit(maxsplit=1),s1.split(maxsplit=1)
# Out:
# (['welcome to python', 'training'], ['welcome', 'to python training'])

# %%
s1 = "welcome to python training.\npython is a general purpose language."
print(s1)
# Out:
# welcome to python training.
# python is a general purpose language.

# %%
s1.split("\n")
# Out:
# ['welcome to python training.', 'python is a general purpose language.']

# %%
s1.splitlines(keepends=False)
# Out:
# ['welcome to python training.', 'python is a general purpose language.']

# %%
words = ['hello','how','are','you','?']
" ".join(words),"#".join(words)
# Out:
# ('hello how are you ?', 'hello#how#are#you#?')
