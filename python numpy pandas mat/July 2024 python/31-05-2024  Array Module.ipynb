# %%
from os import system

# %%
system('mkdir c:\\test_folder')
# Out:
# 0

# %%
system('copy c:\\data\\* c:\\test_folder')
# Out:
# 0

# %%
import array

# %%
x = array.array('I',[8,12,45,34,22,87,80,95,25,70])
type(x)
# Out:
# array.array

# %%
print(x)
# Out:
# array('i', [8, 12, 45, 34, 22, 87, 80, 95, 25, -70])

# %%
x.append(50)
x
# Out:
# array('i', [8, 12, 45, 34, 22, 87, 80, 95, 25, 70, 50])

# %%
x.count(801)
# Out:
# 0

# %%
x.reverse()
x
# Out:
# array('i', [50, 70, 25, 95, 80, 87, 22, 34, 45, 12, 8])

# %%
y = array.array('d',[20.45,56.12,90,30.69,56,39])
y
# Out:
# array('d', [20.45, 56.12, 90.0, 30.69, 56.0, 39.0])

# %%
x.typecode,x.itemsize
# Out:
# ('i', 4)

# %%
x=array.array('i',[1,2,3,4,5,6])
x**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 x=array.array('i',[1,2,3,4,5,6])
# ----> 2 x**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'array.array' and 'int'
