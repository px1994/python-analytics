# %%
def find_sum(n):
    '''This function is created by vamsi to find the sum of the first N Natural Numbers'''
    t=0
    for i in range(1,n+1):
        t+=i
    return t

# %%
find_sum()

# %%
find_sum(20)
# Out:
# 210

# %%
def test_function1(x,y,z):
    return 3*x+4*y+5*z

# %%
test_function1(10,20,30),test_function1(30,10,20),test_function1(20,10,30)
# Out:
# (260, 230, 250)

# %%
test_function1(10,20,30),test_function1(z=30,x=10,y=20),test_function1(y=20,x=10,z=30)
# Out:
# (260, 260, 260)

# %%
test_function1(10,z=30,y=20),test_function1()
# Out:
#   Cell In[15], line 1
#     test_function1(10,z=30,y=20),test_function1(10,z=30,20)
#                                                           ^
# SyntaxError: positional argument follows keyword argument

# %%
def test_function2(x=0,y=0,z=0):
    return 3*x+4*y+5*z

# %%
test_function2(10,20,30),test_function2(10,20),test_function2(10),test_function2()
# Out:
# (260, 110, 30, 0)

# %%
test_function2(y=10,x=30)
# Out:
# 130
